# %%
path_to_mallet = 'mallet-2.0.8/bin/mallet'
import little_mallet_wrapper
import seaborn
import glob
from pathlib import Path

# %%
directory = "Desktop/Topic_modelling/"

# %%
files = glob.glob(f"{directory}/*.txt")
files
# Out:
# ['Desktop/Topic_modelling/Tampon_tax_factiva_final.txt']

# %%
training_data = []
for file in files:
    text = open(file, encoding='utf-8').read()
    processed_text = little_mallet_wrapper.process_string(text, numbers='remove')
    training_data.append(processed_text)

# %%
original_texts = []
for file in files:
    text = open(file, encoding='utf-8').read()
    original_texts.append(text)

# %%
obit_titles = [Path(file).stem for file in files]

# %%
obit_titles
# Out:
# ['Tampon_tax_factiva_final']

# %%
little_mallet_wrapper.print_dataset_stats(training_data)
# Out:
# Number of Documents: 1
# Mean Number of Words per Document: 123153.0
# Vocabulary Size: 14996

# %%
num_topics = 15

# %%
training_data = training_data

# %%
#Change to your desired output directory
output_directory_path = 'Desktop/topic-model-output/Factiva/Tampon_tax'

#No need to change anything below here
Path(f"{output_directory_path}").mkdir(parents=True, exist_ok=True)

path_to_training_data           = f"{output_directory_path}/training.txt"
path_to_formatted_training_data = f"{output_directory_path}/mallet.training"
path_to_model                   = f"{output_directory_path}/mallet.model.{str(num_topics)}"
path_to_topic_keys              = f"{output_directory_path}/mallet.topic_keys.{str(num_topics)}"
path_to_topic_distributions     = f"{output_directory_path}/mallet.topic_distributions.{str(num_topics)}"

# %%
little_mallet_wrapper.quick_train_topic_model(path_to_mallet,
                                             output_directory_path,
                                             num_topics,
                                             training_data)
# Out:
# Importing data...
# Complete
# Training topic model...
# Complete
# ([['buy',
#    'robinson',
#    'classified',
#    'prompted',
#    'scotch',
#    'mix',
#    'charity',
#    'names',
#    'consistent',
#    'uxury',
#    'obstetrics',
#    'landscape',
#    'limitations',
#    'stands',
#    'denied',
#    'journey',
#    'reproduction',
#    'communities',
#    'purchasing',
#    'ballots'],
#   ['idaho',
#    'weather',
#    'usually',
#    'gm/hbc',
#    'metoo',
#    'enter',
#    'surveyed',
#    'payment',
#    'aggressive',
#    'jason',
#    'bathrooms',
#    'healthy',
#    'traction',
#    'analysts',
#    'cpg',
#    'pleasure',
#    'angry',
#    'surveillance',
#    'landfills',
#    'acting'],
#   ['protections',
#    'harassment',
#    'format',
#    'moves',
#    'funds',
#    'german',
#    'weigh',
#    'god',
#    'ideal',
#    'average',
#    'blasio',
#    'keeps',
#    'chance',
#    'driven',
#    'basic',
#    'prostitution',
#    'compton',
#    'complexity',
#    'analyst',
#    'alongside'],
#   ['tax',
#    'products',
#    'women',
#    'said',
#    'state',
#    'new',
#    'tampons',
#    'sales',
#    'menstrual',
#    'would',
#    'year',
#    'tampon',
#    'bill',
#    'states',
#    'hygiene',
#    'york',
#    'one',
#    'period',
#    'feminine',
#    'also'],
#   ['equally',
#    'legalize',
#    'find',
#    'crazy',
#    'wegmans',
#    'prominent',
#    'bobel',
#    'walls',
#    'rachel',
#    'immigration',
#    'shot',
#    'reduction',
#    'speed',
#    'oil',
#    'struck',
#    'ban',
#    'basically',
#    'giant',
#    'encouraging',
#    'opening'],
#   ['term',
#    'shelf',
#    'required',
#    'abortions',
#    'parity',
#    'experiences',
#    'lasting',
#    'nowhere',
#    'rent',
#    'niederhauser',
#    'glenn',
#    'knowledge',
#    'seemed',
#    'collaborate',
#    'streaming',
#    'confederate',
#    'sponges',
#    'indfed',
#    'filled',
#    'adequate'],
#   ['fresh',
#    'exclude',
#    'conversation',
#    'roy',
#    'brookline',
#    'workforce',
#    'played',
#    'uber',
#    'gross',
#    'acknowledged',
#    'politics',
#    'straight',
#    'independence',
#    'operate',
#    'background',
#    'dedicated',
#    'recognize',
#    'spouse',
#    'recommended',
#    'entirely'],
#   ['immediate',
#    'uterus',
#    'older',
#    'regardless',
#    'fowler',
#    'cbo',
#    'roads',
#    'accessibility',
#    'challenging',
#    'concealed',
#    'required',
#    'yoga',
#    'consultant',
#    'workers',
#    'returned',
#    'refugees',
#    'marks',
#    'technicians',
#    'advances',
#    'healthy'],
#   ['alabama',
#    'boxed',
#    'worse',
#    'convention',
#    'unfairly',
#    'outrage',
#    'mentions',
#    'severe',
#    'rouge',
#    'aim',
#    'ferreras',
#    'network',
#    'jokes',
#    'bedekar',
#    'economics',
#    'frank',
#    'infection',
#    'collectively',
#    'drives',
#    'scenario'],
#   ['providence',
#    'eastern',
#    'championed',
#    'originally',
#    'false',
#    'budgets',
#    'high',
#    'cannabis',
#    'comedy',
#    'mandated',
#    'instagram',
#    'accusing',
#    'medically',
#    'suffered',
#    'shame',
#    'petocchi',
#    'parity',
#    'oftentimes',
#    'normalize',
#    'flight'],
#   ['date',
#    'backs',
#    'russia',
#    'turnout',
#    'given',
#    'try',
#    'filers',
#    'legendary',
#    'speaks',
#    'kansas',
#    'blackhawks',
#    'letters',
#    'intends',
#    'meaningful',
#    'current',
#    'characterized',
#    'forecast',
#    'weighing',
#    'roducts',
#    'tangible'],
#   ['institutions',
#    'response',
#    'son',
#    'greenhouse',
#    'vegas',
#    'require',
#    'coaches',
#    'retailers',
#    'pledged',
#    'proof',
#    'class',
#    'elaine',
#    'governing',
#    'rick',
#    'sound',
#    'china',
#    'plaintiffs',
#    'show',
#    'supports',
#    'john'],
#   ['snow',
#    'unit',
#    'creation',
#    'link',
#    'drawn',
#    'gathered',
#    'sarah',
#    'universal',
#    'laying',
#    'zika',
#    'parks',
#    'defending',
#    'breast',
#    'entrepreneur',
#    'prosecutor',
#    'authors',
#    'endorsed',
#    'range',
#    'full',
#    'things'],
#   ['like',
#    'english',
#    'first',
#    'legislation',
#    'girls',
#    'pay',
#    'two',
#    'industry',
#    'support',
#    'revenue',
#    'old',
#    'officials',
#    'members',
#    'among',
#    'exemption',
#    'garcia',
#    'found',
#    'buy',
#    'online',
#    'democrat'],
#   ['date',
#    'cheaper',
#    'cream',
#    'wilson',
#    'statute',
#    'anywhere',
#    'yetter',
#    'thirty',
#    'sessions',
#    'northern',
#    'ingredients',
#    'jim',
#    'countless',
#    'everyday',
#    'says',
#    'progressives',
#    'commitment',
#    'booze',
#    'secure',
#    'salary']],
#  [[0.011583214240582158,
#    0.011298934824978958,
#    0.016121881528721377,
#    0.6610694920948169,
#    0.013133885349976386,
#    0.01398662443393421,
#    0.013328808256075355,
#    0.014790092976694107,
#    0.013848316011826067,
#    0.011793989821315161,
#    0.011907640806662834,
#    0.014831116034749828,
#    0.014205959238673212,
#    0.16434920742845427,
#    0.013750836952539152]])

# %%
topics = little_mallet_wrapper.load_topic_keys(path_to_topic_keys)

for topic_number, topic in enumerate(topics):
    print(f"✨Topic {topic_number}✨\n\n{topic}\n")
# Out:
# ✨Topic 0✨
#
# ['buy', 'robinson', 'classified', 'prompted', 'scotch', 'mix', 'charity', 'names', 'consistent', 'uxury', 'obstetrics', 'landscape', 'limitations', 'stands', 'denied', 'journey', 'reproduction', 'communities', 'purchasing', 'ballots']
#
# ✨Topic 1✨
#
# ['idaho', 'weather', 'usually', 'gm/hbc', 'metoo', 'enter', 'surveyed', 'payment', 'aggressive', 'jason', 'bathrooms', 'healthy', 'traction', 'analysts', 'cpg', 'pleasure', 'angry', 'surveillance', 'landfills', 'acting']
#
# ✨Topic 2✨
#
# ['protections', 'harassment', 'format', 'moves', 'funds', 'german', 'weigh', 'god', 'ideal', 'average', 'blasio', 'keeps', 'chance', 'driven', 'basic', 'prostitution', 'compton', 'complexity', 'analyst', 'alongside']
#
# ✨Topic 3✨
#
# ['tax', 'products', 'women', 'said', 'state', 'new', 'tampons', 'sales', 'menstrual', 'would', 'year', 'tampon', 'bill', 'states', 'hygiene', 'york', 'one', 'period', 'feminine', 'also']
#
# ✨Topic 4✨
#
# ['equally', 'legalize', 'find', 'crazy', 'wegmans', 'prominent', 'bobel', 'walls', 'rachel', 'immigration', 'shot', 'reduction', 'speed', 'oil', 'struck', 'ban', 'basically', 'giant', 'encouraging', 'opening']
#
# ✨Topic 5✨
#
# ['term', 'shelf', 'required', 'abortions', 'parity', 'experiences', 'lasting', 'nowhere', 'rent', 'niederhauser', 'glenn', 'knowledge', 'seemed', 'collaborate', 'streaming', 'confederate', 'sponges', 'indfed', 'filled', 'adequate']
#
# ✨Topic 6✨
#
# ['fresh', 'exclude', 'conversation', 'roy', 'brookline', 'workforce', 'played', 'uber', 'gross', 'acknowledged', 'politics', 'straight', 'independence', 'operate', 'background', 'dedicated', 'recognize', 'spouse', 'recommended', 'entirely']
#
# ✨Topic 7✨
#
# ['immediate', 'uterus', 'older', 'regardless', 'fowler', 'cbo', 'roads', 'accessibility', 'challenging', 'concealed', 'required', 'yoga', 'consultant', 'workers', 'returned', 'refugees', 'marks', 'technicians', 'advances', 'healthy']
#
# ✨Topic 8✨
#
# ['alabama', 'boxed', 'worse', 'convention', 'unfairly', 'outrage', 'mentions', 'severe', 'rouge', 'aim', 'ferreras', 'network', 'jokes', 'bedekar', 'economics', 'frank', 'infection', 'collectively', 'drives', 'scenario']
#
# ✨Topic 9✨
#
# ['providence', 'eastern', 'championed', 'originally', 'false', 'budgets', 'high', 'cannabis', 'comedy', 'mandated', 'instagram', 'accusing', 'medically', 'suffered', 'shame', 'petocchi', 'parity', 'oftentimes', 'normalize', 'flight']
#
# ✨Topic 10✨
#
# ['date', 'backs', 'russia', 'turnout', 'given', 'try', 'filers', 'legendary', 'speaks', 'kansas', 'blackhawks', 'letters', 'intends', 'meaningful', 'current', 'characterized', 'forecast', 'weighing', 'roducts', 'tangible']
#
# ✨Topic 11✨
#
# ['institutions', 'response', 'son', 'greenhouse', 'vegas', 'require', 'coaches', 'retailers', 'pledged', 'proof', 'class', 'elaine', 'governing', 'rick', 'sound', 'china', 'plaintiffs', 'show', 'supports', 'john']
#
# ✨Topic 12✨
#
# ['snow', 'unit', 'creation', 'link', 'drawn', 'gathered', 'sarah', 'universal', 'laying', 'zika', 'parks', 'defending', 'breast', 'entrepreneur', 'prosecutor', 'authors', 'endorsed', 'range', 'full', 'things']
#
# ✨Topic 13✨
#
# ['like', 'english', 'first', 'legislation', 'girls', 'pay', 'two', 'industry', 'support', 'revenue', 'old', 'officials', 'members', 'among', 'exemption', 'garcia', 'found', 'buy', 'online', 'democrat']
#
# ✨Topic 14✨
#
# ['date', 'cheaper', 'cream', 'wilson', 'statute', 'anywhere', 'yetter', 'thirty', 'sessions', 'northern', 'ingredients', 'jim', 'countless', 'everyday', 'says', 'progressives', 'commitment', 'booze', 'secure', 'salary']

# %%
topic_distributions = little_mallet_wrapper.load_topic_distributions(path_to_topic_distributions)

# %%
topic_distributions[0]
# Out:
# [0.011583214240582158,
#  0.011298934824978958,
#  0.016121881528721377,
#  0.6610694920948169,
#  0.013133885349976386,
#  0.01398662443393421,
#  0.013328808256075355,
#  0.014790092976694107,
#  0.013848316011826067,
#  0.011793989821315161,
#  0.011907640806662834,
#  0.014831116034749828,
#  0.014205959238673212,
#  0.16434920742845427,
#  0.013750836952539152]
